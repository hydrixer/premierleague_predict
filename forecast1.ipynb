# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from ipywidgets import Button, Output, VBox, Dropdown, Text
from IPython.display import display
from bs4 import BeautifulSoup
import pandas as pd
from io import StringIO
import requests
import time

# %%
df1 = pd.read_csv('matches2.csv')
df2 = pd.read_csv('matches.csv')
df2 = df2.drop(columns=['Unnamed: 0','notes','match report','formation','pk','pkatt'])
df1 = df1.drop(columns=['Unnamed: 0','notes','match report','formation','opp formation','pk','pkatt'])

matches = pd.concat([df1,df2], axis=0)

# %%
matches['date'] = pd.to_datetime(matches['date'], errors='coerce')
matches.dropna(subset=['date'])
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1    2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2    2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3    2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 4    2024-09-21  15:00  Premier League   Matchweek 5  Sat  Home      W  3.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 1384 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 1385 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 1386 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 1387 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 1388 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#        ga         opponent  ...  poss  attendance          captain  \
# 0     0.0     Ipswich Town  ...  62.0     30014.0  Virgil van Dijk
# 1     0.0        Brentford  ...  62.0     60017.0  Virgil van Dijk
# 2     0.0   Manchester Utd  ...  47.0     73738.0  Virgil van Dijk
# 3     1.0  Nott'ham Forest  ...  68.0     60344.0  Virgil van Dijk
# 4     0.0      Bournemouth  ...  58.0     60347.0  Virgil van Dijk
# ...   ...              ...  ...   ...         ...              ...
# 1384  4.0        Tottenham  ...  34.0         NaN        John Egan
# 1385  2.0   Crystal Palace  ...  50.0         NaN        John Egan
# 1386  0.0          Everton  ...  38.0         NaN        John Egan
# 1387  1.0    Newcastle Utd  ...  50.0     10000.0        John Egan
# 1388  0.0          Burnley  ...  41.0      5000.0        John Egan
#
#               referee    sh   sot  dist   fk  season              team
# 0        Tim Robinson  18.0   5.0  14.8  0.0  2025.0         Liverpool
# 1      Stuart Attwell  19.0   8.0  13.6  1.0  2025.0         Liverpool
# 2      Anthony Taylor  11.0   3.0  13.4  0.0  2025.0         Liverpool
# 3      Michael Oliver  14.0   5.0  14.9  0.0  2025.0         Liverpool
# 4     Tony Harrington  19.0  12.0  16.6  0.0  2025.0         Liverpool
# ...               ...   ...   ...   ...  ...     ...               ...
# 1384   Andre Marriner   8.0   1.0  17.4  0.0  2021.0  Sheffield United
# 1385     Simon Hooper   7.0   0.0  11.4  1.0  2021.0  Sheffield United
# 1386    Jonathan Moss  10.0   3.0  17.0  0.0  2021.0  Sheffield United
# 1387     Robert Jones  11.0   1.0  16.0  1.0  2021.0  Sheffield United
# 1388     Kevin Friend  12.0   3.0  17.0  0.0  2021.0  Sheffield United
#
# [2527 rows x 22 columns]

# %%
matches['result_encoded'] = matches['result'].map({'W':0, 'L':1, 'D':1})
matches['venue_encoded'] = matches['venue'].map({'Home':0, 'Away':1})
le = LabelEncoder()
matches['referee'] = le.fit_transform(matches['referee'])

# %%
def calculate_last_5_stats(team, date):
    """
    计算给定球队在某日期前的过去五场比赛表现，若不足五场，则返回实际值
    """
    past_matches = matches[
        ((matches['team'] == team)) & (matches['date'] < date)
    ].tail(5)

    total_matches = len(past_matches)
    wins = ((past_matches['team'] == team) & (past_matches['result'] == 'W')).sum()

    # 计算射门和射正数
    shots_for = past_matches['sh'].sum()
    shots_on_target_for = past_matches['sot'].sum()
    avg_shots_for = shots_for / total_matches if total_matches > 0 else 0
    avg_shots_on_target_for = shots_on_target_for / total_matches if total_matches > 0 else 0

    gf = past_matches['gf'].sum()
    ga = past_matches['ga'].sum()
    avg_gf = gf / total_matches if total_matches > 0 else 0
    avg_ga = ga / total_matches if total_matches > 0 else 0

    return wins, avg_shots_for, avg_shots_on_target_for, avg_gf, avg_ga

matches = matches.sort_values(by=['team', 'date']).reset_index(drop=True)
matches[['Last5Wins', 'Last5AvgSh', 'Last5AvgSot', 'Last5AvgGf', 'Last5AvgGa']] = matches.apply(
    lambda row: pd.Series(calculate_last_5_stats(row['team'], row['date'])),
    axis=1
)

# %%
merged_df = pd.merge(
    matches[matches["venue"] == "Home"],
    matches[matches["venue"] == "Away"],
    on=["date", "time", "referee", "comp", "day"],
    suffixes=("_home", "_away")
)

merged_df = merged_df[[
    "date", "referee",
    "team_home", "team_away", "result_encoded_home",
    "gf_home", "ga_home", "sh_home", "sot_home",'Last5Wins_home', 'Last5AvgSh_home', 'Last5AvgSot_home', 'Last5AvgGf_home', 'Last5AvgGa_home',
    "gf_away", "ga_away", "sh_away", "sot_away",'Last5Wins_away', 'Last5AvgSh_away', 'Last5AvgSot_away', 'Last5AvgGf_away', 'Last5AvgGa_away'
]]

# %%
merged_df['date'] = pd.to_datetime(merged_df['date'])

# 对每个 team_home 取 date 最新的行
latest_rows = merged_df.loc[merged_df.groupby('team_home')['date'].idxmax()]

merged_df = merged_df.drop(columns=["team_home", "team_away"])

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

feature_cols = [
    'Last5Wins_home', 'Last5AvgSh_home', 'Last5AvgSot_home', 'Last5AvgGf_home', 'Last5AvgGa_home',
    'Last5Wins_away', 'Last5AvgSh_away', 'Last5AvgSot_away', 'Last5AvgGf_away', 'Last5AvgGa_away'
]

# 目标列
target_col = "result_encoded_home"

x = merged_df[feature_cols]
y = merged_df[target_col]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=10)
x_test

# 初始化随机森林模型
rf = RandomForestClassifier(n_estimators=200, min_samples_leaf=4, min_samples_split=10, random_state=10, max_depth=10)

# 训练模型
rf.fit(x_train, y_train)

y_pred = rf.predict(x_test)

# 评估模型
accuracy = accuracy_score(y_test, y_pred)
print(f"测试集准确率: {accuracy:.2f}")

print("分类报告:")
print(classification_report(y_test, y_pred))
# Out:
# 测试集准确率: 0.62
# 分类报告:
#               precision    recall  f1-score   support
#
#          0.0       0.54      0.43      0.48       102
#          1.0       0.66      0.75      0.70       148
#
#     accuracy                           0.62       250
#    macro avg       0.60      0.59      0.59       250
# weighted avg       0.61      0.62      0.61       250

# %%
# Function to save team data based on team names
def save_team_data(home_team_name, away_team_name):
    home_rows = latest_rows[latest_rows['team_home'] == home_team_name]
    away_rows = latest_rows[latest_rows['team_home'] == away_team_name]

    if not home_rows.empty and not away_rows.empty:
        home_selected_row = home_rows.iloc[0]
        away_selected_row = away_rows.iloc[0]
        result_df = pd.DataFrame([{
            "Last5Wins_home": home_selected_row["Last5Wins_home"], 
            "Last5AvgSh_home": home_selected_row["Last5AvgSh_home"], 
            "Last5AvgSot_home": home_selected_row["Last5AvgSot_home"], 
            "Last5AvgGf_home": home_selected_row["Last5AvgGf_home"], 
            "Last5AvgGa_home": home_selected_row["Last5AvgGa_home"], 
            "Last5Wins_away": away_selected_row["Last5Wins_home"], 
            "Last5AvgSh_away": away_selected_row["Last5AvgSh_home"], 
            "Last5AvgSot_away": away_selected_row["Last5AvgSot_home"], 
            "Last5AvgGf_away": away_selected_row["Last5AvgGf_home"], 
            "Last5AvgGa_away": away_selected_row["Last5AvgGa_home"]
        }])
        return result_df
    else:
        return pd.DataFrame()


# # Output widget to display results
# output = Output()

# # Button click event handler
# def on_button_click(home_team_name, away_team_name):
#     output.clear_output()
#     with output:
#         if home_team_name and away_team_name:
#             result_df = save_team_data(home_team_name, away_team_name)
#             if not result_df.empty:
#                 print("Matched data")
#                 display(result_df)
                
#                 # Use the model to predict the result
#                 predicted_result = rf.predict(result_df)
#                 result_label = "w" if predicted_result[0] == 0 else "D/L"
#                 print(f"Prediction result: {result_label}")
#             else:
#                 print(f"No rows found for home team '{home_team_name}' or away team '{away_team_name}'.")


# # Dropdowns for selecting home and away teams
# home_team_dropdown = Dropdown(options=latest_rows['team_home'].unique(), description="Home Team:")
# away_team_dropdown = Dropdown(options=latest_rows['team_home'].unique(), description="Away Team:")

# # Text widget for inputting referee name


# # Button to trigger prediction
# predict_button = Button(description="Predict Result")
# predict_button.on_click(lambda x: on_button_click(home_team_dropdown.value, away_team_dropdown.value))

# # Display the widgets
# display(VBox([home_team_dropdown, away_team_dropdown, predict_button, output]))

# %%
def next_fixture():
    fixtures = []
    standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"
    data = requests.get(standings_url)

    soup = BeautifulSoup(data.text, features="lxml")
    standings_table = soup.select('table.stats_table')[0]
    links = standings_table.find_all('a')
    links = [l.get("href") for l in links]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    for team_url in team_urls:
        data = requests.get(team_url)
        team_name = team_url.split('/')[-1].replace("-Stats", "").replace("-", " ")
        matches = pd.read_html(StringIO(data.text), match="Scores & Fixtures")[0]
        matches['Date'] = pd.to_datetime(matches['Date'], errors='coerce')  #获取下一场比赛队伍
        future_matches = matches[
            (matches['Date'].dt.date >= pd.Timestamp.now().normalize().date())
        ]
        id = 0
        for i in range(0,len(future_matches)):
            print(future_matches.iloc[i]['Comp'])
            if 'Premier League' in future_matches.iloc[i]['Comp']:
                id = i
                break
        print(id)
        if future_matches.iloc[id]['Venue'] == 'Home':   #only add infomation HOME-AWAY
            match_record = {
                'date':future_matches.iloc[id]['Date'].date(),
                'home':team_name,
                'away':future_matches.iloc[id]['Opponent']
            }
            fixtures.append(match_record)
            print(f"date:{future_matches.iloc[id]['Date'].date()}, {team_name} VS {future_matches.iloc[id]['Opponent']}")
        else:
            continue
        time.sleep(20)
    return fixtures

# %%
fixtures = []
fixtures = next_fixture()
# Out:
# Premier League
# 0
# date:2025-01-05, Liverpool VS Manchester Utd
# EFL Cup
# FA Cup
# Premier League
# 2
# date:2025-01-15, Arsenal VS Tottenham
# Premier League
# 0
# FA Cup
# Premier League
# 1
# date:2025-01-14, Chelsea VS Bournemouth
# EFL Cup
# FA Cup
# Premier League
# 2
# date:2025-01-15, Newcastle United VS Wolves
# FA Cup
# Premier League
# 1
# FA Cup
# Premier League
# 1
# FA Cup
# Premier League
# 1
# Premier League
# 0
# date:2025-01-05, Fulham VS Ipswich Town
# FA Cup
# Premier League
# 1
# FA Cup
# Premier League
# 1
# date:2025-01-14, Brentford VS Manchester City
# EFL Cup
# FA Cup
# Premier League
# 2
# FA Cup
# Premier League
# 1
# date:2025-01-14, West Ham United VS Fulham
# Premier League
# 0
# FA Cup
# Premier League
# 1
# FA Cup
# Premier League
# 1
# date:2025-01-15, Everton VS Aston Villa
# Premier League
# 0
# date:2025-01-06, Wolverhampton Wanderers VS Nott'ham Forest
# Premier League
# 0
# FA Cup
# Premier League
# 1
# date:2025-01-15, Leicester City VS Crystal Palace
# FA Cup
# Premier League
# 1

# %%
for match in fixtures:
    if match['home'] == 'Manchester Utd':
        match['home'] = 'Manchester United'
    if match['away'] == 'Manchester Utd':
        match['away'] = 'Manchester United'
    if match['home'] == 'West Ham':
        match['home'] = 'West Ham United'
    if match['away'] == 'West Ham':
        match['away'] = 'West Ham United'
    if match['home'] == 'Newcastle Utd':
        match['home'] = 'Newcastle United'
    if match['away'] == 'Newcastle Utd':
        match['away'] = 'Newcastle United'
    if match['home'] == 'Nott\'ham Forest':
        match['home'] = 'Nottingham Forest'
    if match['away'] == 'Nott\'ham Forest':
        match['away'] = 'Nottingham Forest'
       
predicted_results = []

data_to_save = []
for fixture in fixtures:
    print(fixture['away'])
    home_team = fixture['home']
    away_team = fixture['away']
    date = fixture['date']
    prediction = rf.predict(save_team_data(home_team, away_team))
    result_label = "Win" if prediction == 0 else "Draw or Lose"
    data_to_save.append([date, home_team, away_team, result_label])

df = pd.DataFrame(data_to_save, columns=["Date", "Home Team", "Away Team", "Result"])

df.to_excel("fixtures_predictions.xlsx", index=False)
# Out:
# Manchester United
# Tottenham
# c:\Users\rkw20\OneDrive\Desktop\CODE\id2223_pro\.venv\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 27
#      25 away_team = fixture['away']
#      26 date = fixture['date']
# ---> 27 prediction = rf.predict(save_team_data(home_team, away_team))
#      28 result_label = "Win" if prediction == 0 else "Draw or Lose"
#      29 data_to_save.append([date, home_team, away_team, result_label])
#
# File c:\Users\rkw20\OneDrive\Desktop\CODE\id2223_pro\.venv\lib\site-packages\sklearn\ensemble\_forest.py:904, in ForestClassifier.predict(self, X)
#     883 def predict(self, X):
#     884     """
#     885     Predict class for X.
#     886
#    (...)
#     902         The predicted classes.
#     903     """
# --> 904     proba = self.predict_proba(X)
#     906     if self.n_outputs_ == 1:
#     907         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File c:\Users\rkw20\OneDrive\Desktop\CODE\id2223_pro\.venv\lib\site-packages\sklearn\ensemble\_forest.py:946, in ForestClassifier.predict_proba(self, X)
#     944 check_is_fitted(self)
#     945 # Check data
# --> 946 X = self._validate_X_predict(X)
#     948 # Assign chunk of trees to jobs
#     949 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File c:\Users\rkw20\OneDrive\Desktop\CODE\id2223_pro\.venv\lib\site-packages\sklearn\ensemble\_forest.py:638, in BaseForest._validate_X_predict(self, X)
#     635 else:
#     636     ensure_all_finite = True
# --> 638 X = validate_data(
#     639     self,
#     640     X,
#     641     dtype=DTYPE,
#     642     accept_sparse="csr",
#     643     reset=False,
#     644     ensure_all_finite=ensure_all_finite,
#     645 )
#     646 if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
#     647     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File c:\Users\rkw20\OneDrive\Desktop\CODE\id2223_pro\.venv\lib\site-packages\sklearn\utils\validation.py:2944, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2942         out = X, y
#    2943 elif not no_val_X and no_val_y:
# -> 2944     out = check_array(X, input_name="X", **check_params)
#    2945 elif no_val_X and not no_val_y:
#    2946     out = _check_y(y, **check_params)
#
# File c:\Users\rkw20\OneDrive\Desktop\CODE\id2223_pro\.venv\lib\site-packages\sklearn\utils\validation.py:931, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     927 pandas_requires_conversion = any(
#     928     _pandas_dtype_needs_early_conversion(i) for i in dtypes_orig
#     929 )
#     930 if all(isinstance(dtype_iter, np.dtype) for dtype_iter in dtypes_orig):
# --> 931     dtype_orig = np.result_type(*dtypes_orig)
#     932 elif pandas_requires_conversion and any(d == object for d in dtypes_orig):
#     933     # Force object if any of the dtypes is an object
#     934     dtype_orig = object
#
# ValueError: at least one array or dtype is required
